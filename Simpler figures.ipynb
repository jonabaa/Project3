# %%
import numpy as np
from functions import *
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## Linear SVM

# %%
c_list = [10, 5, 1, 0.1, 0.01, .001]
p_list = ['']
accu = np.array([[0.7463, 0.7530, 0.7683, 0.7837, 0.7678, 0.7023]])

fig, ax = plt.subplots()
im, cbar = heatmap(accu, np.array(p_list), np.array(c_list) , ax = ax, cmap = "YlGn", cbarlabel = '' )
texts = annotate_heatmap(im, valfmt="{x:.4f}")
fig.tight_layout()
plt.show()

# %% [markdown]
# ## MLPs

# %%
# Accuracies from mlp computations
accu = np.array([[0.78103846, 0.78164221, 0.78222034, 0.78616682, 0.78382918,],\
                 [0.78398004, 0.78337646, 0.78380405, 0.78543754, 0.78408112,],\
                 [0.78360279, 0.78513618, 0.78553889, 0.78684586, 0.78714722,],\
                 [0.7842061,  0.78508635, 0.78624259, 0.78820385, 0.78561346,]])
nodes = np.array([1000,1200,1400,1600])
alphas = np.array([.00001, .0001, .001, .01, .1])

fig, ax = plt.subplots()
im, cbar = heatmap(accu, nodes, alphas , ax = ax, cmap = "YlGn", cbarlabel = '' )
texts = annotate_heatmap(im, valfmt="{x:.4f}")
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Poly SVM

# %%
accu = np.array([[0.19706342, 0.19706342],\
                 [0.19932623, 0.19706342],\
                 [0.4123805 , 0.19706342],\
                 [0.61248489, 0.20045765],\
                 [0.76421728, 0.52227571],\
                 [0.75028845, 0.67121641]])

C_list = np.array([0.1, 10, 100, 1000, 100000, 1000000])
degrees = np.array([2, 3])

fig, ax = plt.subplots()
im, cbar = heatmap(accu, C_list, degrees , ax = ax, cmap = "YlGn", cbarlabel = '' )
texts = annotate_heatmap(im, valfmt="{x:.4f}")
fig.tight_layout()
plt.show()
