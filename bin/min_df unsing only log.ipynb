# %%
import numpy as np
import pandas as pd
import re
from sklearn.model_selection import train_test_split
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import random
from sklearn.metrics import r2_score, mean_squared_error, accuracy_score, log_loss
from sklearn import svm #support vector machines
from sklearn.feature_extraction.text import CountVectorizer

from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier

from functions import *

# %%
# First we make a list of dfs. 
# The are 39774 in total, so min_df = i/39774 means 
# include every ingredient that appears in at least i recipies.
df_list = [i/39774 for i in range(1,101)] 
feat_num = []

data = pd.read_json('train.json') 
y = data.cuisine.values
recipie_list_list = data.ingredients.values.tolist()
recipie_string_list = [" ".join(ing) for ing in recipie_list_list]
del data, recipie_list_list

for df in df_list :
    vectorizer = CountVectorizer(min_df = df)
    X = vectorizer.fit_transform(recipie_string_list)
    feat_num.append(len(vectorizer.get_feature_names()))


### Make bar charts of features    
x_pos = np.arange(1,101)    
plt.bar(x_pos, feat_num, align='center', alpha=0.5)
#plt.xticks(x_pos, x_pos)
#plt.ylabel('Usage')
#plt.title('Programming language usage')

#plt.plot(range(1,11), feat_num, "-")
plt.xlabel('recipies')
plt.ylabel('features/ingredients')
plt.show()

# %%
accuracies = []
clf = LogisticRegression()

for df in df_list :
    print("Testing min_df = %f" % df)
    vectorizer = CountVectorizer(min_df = df)
    X = vectorizer.fit_transform(recipie_string_list)
    # Pick the highst cv scores (avarage of fold accuracies)
    score = cross_val_score(clf, X, y, cv=3)
    accuracies.append(np.mean(score))
    print("")
# Out:
# Testing min_df = 0.000025
#
# Testing min_df = 0.000050
#
# Testing min_df = 0.000075
#
# Testing min_df = 0.000101
#
# Testing min_df = 0.000126
#
# Testing min_df = 0.000151
#
# Testing min_df = 0.000176
#
# Testing min_df = 0.000201
#
# Testing min_df = 0.000226
#
# Testing min_df = 0.000251
#
# Testing min_df = 0.000277
#
# Testing min_df = 0.000302
#
# Testing min_df = 0.000327
#
# Testing min_df = 0.000352
#
# Testing min_df = 0.000377
#
# Testing min_df = 0.000402
#
# Testing min_df = 0.000427
#
# Testing min_df = 0.000453
#
# Testing min_df = 0.000478
#
# Testing min_df = 0.000503
#
# Testing min_df = 0.000528
#
# Testing min_df = 0.000553
#
# Testing min_df = 0.000578
#
# Testing min_df = 0.000603
#
# Testing min_df = 0.000629
#
# Testing min_df = 0.000654
#
# Testing min_df = 0.000679
#
# Testing min_df = 0.000704
#
# Testing min_df = 0.000729
#
# Testing min_df = 0.000754
#
# Testing min_df = 0.000779
#
# Testing min_df = 0.000805
#
# Testing min_df = 0.000830
#
# Testing min_df = 0.000855
#
# Testing min_df = 0.000880
#
# Testing min_df = 0.000905
#
# Testing min_df = 0.000930
#
# Testing min_df = 0.000955
#
# Testing min_df = 0.000981
#
# Testing min_df = 0.001006
#
# Testing min_df = 0.001031
#
# Testing min_df = 0.001056
#
# Testing min_df = 0.001081
#
# Testing min_df = 0.001106
#
# Testing min_df = 0.001131
#
# Testing min_df = 0.001157
#
# Testing min_df = 0.001182
#
# Testing min_df = 0.001207
#
# Testing min_df = 0.001232
#
# Testing min_df = 0.001257
#
# Testing min_df = 0.001282
#
# Testing min_df = 0.001307
#
# Testing min_df = 0.001333
#
# Testing min_df = 0.001358
#
# Testing min_df = 0.001383
#
# Testing min_df = 0.001408
#
# Testing min_df = 0.001433
#
# Testing min_df = 0.001458
#
# Testing min_df = 0.001483
#
# Testing min_df = 0.001509
#
# Testing min_df = 0.001534
#
# Testing min_df = 0.001559
#
# Testing min_df = 0.001584
#
# Testing min_df = 0.001609
#
# Testing min_df = 0.001634
#
# Testing min_df = 0.001659
#
# Testing min_df = 0.001685
#
# Testing min_df = 0.001710
#
# Testing min_df = 0.001735
#
# Testing min_df = 0.001760
#
# Testing min_df = 0.001785
#
# Testing min_df = 0.001810
#
# Testing min_df = 0.001835
#
# Testing min_df = 0.001861
#
# Testing min_df = 0.001886
#
# Testing min_df = 0.001911
#
# Testing min_df = 0.001936
#
# Testing min_df = 0.001961
#
# Testing min_df = 0.001986
#
# Testing min_df = 0.002011
#
# Testing min_df = 0.002037
#
# Testing min_df = 0.002062
#
# Testing min_df = 0.002087
#
# Testing min_df = 0.002112
#
# Testing min_df = 0.002137
#
# Testing min_df = 0.002162
#
# Testing min_df = 0.002187
#
# Testing min_df = 0.002213
#
# Testing min_df = 0.002238
#
# Testing min_df = 0.002263
#
# Testing min_df = 0.002288
#
# Testing min_df = 0.002313
#
# Testing min_df = 0.002338
#
# Testing min_df = 0.002363
#
# Testing min_df = 0.002388
#
# Testing min_df = 0.002414
#
# Testing min_df = 0.002439
#
# Testing min_df = 0.002464
#
# Testing min_df = 0.002489
#
# Testing min_df = 0.002514

# %%
### Make bar charts of accuracies    
x_pos = np.arange(1,101)    
plt.plot(x_pos, accuracies)
#plt.xticks(x_pos, x_pos)
#plt.ylabel('Usage')
#plt.title('Programming language usage')

#plt.plot(range(1,11), feat_num, "-")
plt.xlabel('recipies')
plt.ylabel('accuracy')
plt.show()

# %%
x = [2,3,4,5,6,7,8,9,10]
prob = [(0.8**n + 0.2**n) for n in x]
plt.bar(x,prob)
plt.show()
print(prob)
# Out:
# [0.6800000000000002, 0.5200000000000001, 0.41120000000000007, 0.32800000000000007, 0.2622080000000001, 0.20972800000000008, 0.1677747200000001, 0.13421824000000007, 0.10737428480000005]

# %%
print(clean('low-fat 3d'))

X, y, features = get_design_matrix(cleaning_function = clean, min_df = 3)
print(len(features))
print(features)
# Out:
# low fat d
# 2176
# ['abura', 'acai', 'accent', 'achiote', 'acid', 'acini', 'ackee', 'acorn', 'acting', 'active', 'added', 'adobo', 'adzuki', 'agar', 'agave', 'age', 'aged', 'ahi', 'aioli', 'ajinomoto', 'ajwain', 'aka', 'alaskan', 'albacore', 'alcohol', 'ale', 'aleppo', 'alfalfa', 'alfredo', 'all', 'allspice', 'almond', 'almonds', 'amaretti', 'amaretto', 'amber', 'amchur', 'american', 'aminos', 'ampalaya', 'anaheim', 'ancho', 'anchovies', 'anchovy', 'and', 'andouille', 'anejo', 'angel', 'anglaise', 'angostura', 'anise', 'anisette', 'anjou', 'annatto', 'apple', 'apples', 'applesauce', 'applewood', 'apricot', 'apricots', 'arbol', 'arborio', 'arhar', 'armagnac', 'arrowroot', 'artichok', 'artichoke', 'artichokes', 'artisan', 'arugula', 'asada', 'asadero', 'asafetida', 'asafoetida', 'asiago', 'asian', 'asparagus', 'assorted', 'atta', 'au', 'avocado', 'avocados', 'aãai', 'baby', 'back', 'bacon', 'bagels', 'bags', 'baguette', 'baileys', 'baked', 'baking', 'balance', 'balls', 'balm', 'balsamic', 'balsamico', 'bamboo', 'banana', 'bananas', 'banger', 'banh', 'bar', 'barbecue', 'barbecued', 'barilla', 'barley', 'bars', 'bartlett', 'base', 'basil', 'basmati', 'bass', 'baton', 'batter', 'bawang', 'bay', 'bbq', 'bean', 'beans', 'beansprouts', 'beaten', 'bechamel', 'beef', 'beefsteak', 'beer', 'beet', 'beets', 'belgian', 'believe', 'bell', 'bells', 'belly', 'bellâ', 'bengal', 'bengali', 'beni', 'bens', 'berries', 'bertolli', 'bertolliâ', 'besan', 'best', 'bestâ', 'bhindi', 'bianco', 'bibb', 'bicarbonate', 'bihon', 'bing', 'bird', 'biryani', 'biscotti', 'biscuit', 'biscuits', 'bisquick', 'bits', 'bitter', 'bitters', 'bittersweet', 'black', 'blackberries', 'blackberry', 'blackening', 'blade', 'blanc', 'blanched', 'blanco', 'blend', 'bliss', 'blood', 'bloody', 'blossom', 'blossoms', 'blue', 'blueberries', 'boar', 'bocconcini', 'boil', 'boiled', 'boiling', 'bok', 'bolillo', 'bone', 'boned', 'boneless', 'bones', 'bonito', 'bonnet', 'borlotti', 'bosc', 'boston', 'bottle', 'bottled', 'bottom', 'bottoms', 'boudin', 'bought', 'bouillon', 'bouquet', 'bourbon', 'bow', 'bows', 'braeburn', 'bragg', 'braising', 'bran', 'brand', 'brandy', 'branzino', 'brats', 'bread', 'breadcrumbs', 'breadstick', 'breakfast', 'breast', 'breasts', 'brewed', 'brie', 'brine', 'brioche', 'brisket', 'broad', 'broccoli', 'broccolini', 'broil', 'broiler', 'broth', 'brown', 'brownie', 'brownies', 'browning', 'browns', 'brussels', 'bucatini', 'buckwheat', 'buds', 'buffalo', 'bulb', 'bulgur', 'bulk', 'bun', 'buns', 'burdock', 'burger', 'burgers', 'burgundi', 'burgundy', 'burrata', 'butt', 'butter', 'buttercream', 'butterflied', 'buttermilk', 'butternut', 'butterscotch', 'buttery', 'butterâ', 'button', 'cabbage', 'cabernet', 'cacao', 'cachaca', 'cactus', 'caesar', 'cajeta', 'cajun', 'cake', 'cakes', 'calabaza', 'calamansi', 'calamari', 'calamata', 'calf', 'california', 'calimyrna', 'callaloo', 'calorie', 'calvados', 'camembert', 'campanelle', 'campari', 'campbells', 'canadian', 'candied', 'candlenuts', 'candy', 'cane', 'canela', 'canes', 'canned', 'cannellini', 'cannelloni', 'canning', 'cannoli', 'canola', 'cant', 'cantal', 'cantaloupe', 'canton', 'capellini', 'caper', 'capers', 'capicola', 'caps', 'capsicum', 'caramel', 'caramels', 'caraway', 'carbonated', 'carcass', 'cardamom', 'cardamon', 'caribbean', 'carnaroli', 'carnation', 'carne', 'carnitas', 'carpaccio', 'carrot', 'carrots', 'casera', 'cashew', 'cashews', 'casings', 'cassava', 'cassia', 'cassis', 'caster', 'catalina', 'catfish', 'catsup', 'caul', 'cauliflower', 'cavatappi', 'cavatelli', 'caviar', 'cavolo', 'cayenne', 'celery', 'celtic', 'center', 'cereal', 'chaat', 'challa', 'cham', 'chambord', 'champagne', 'chana', 'channa', 'chanterelle', 'chapati', 'char', 'chard', 'chardonnay', 'chat', 'chayotes', 'cheddar', 'cheeks', 'chees', 'cheese', 'cheesi', 'chenpi', 'cherries', 'cherry', 'cherrystone', 'chervil', 'chestnut', 'chestnuts', 'chevre', 'chia', 'chianti', 'chicken', 'chickens', 'chickpea', 'chickpeas', 'chiffonade', 'chihuahua', 'chile', ' ...
